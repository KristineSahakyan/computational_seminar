# %%
import pandas as pd
df = pd.read_csv('FemaleTopManagers.csv')
print(df)
df.describe()
# Out:
#                           Entity Code  Year  Firms with female top manager
# 0                    Afghanistan  AFG  2008                       0.700000
# 1                    Afghanistan  AFG  2014                       4.700000
# 2    Africa Eastern and Southern  NaN  2019                      15.000000
# 3    Africa Eastern and Southern  NaN  2020                      18.361111
# 4     Africa Western and Central  NaN  2020                      13.743750
# ..                           ...  ...   ...                            ...
# 320                        Yemen  YEM  2013                       1.600000
# 321                       Zambia  ZMB  2013                      22.500000
# 322                       Zambia  ZMB  2019                      12.900000
# 323                     Zimbabwe  ZWE  2011                      17.400000
# 324                     Zimbabwe  ZWE  2016                      16.300000
#
# [325 rows x 4 columns]
# ...

# %%
df1 = pd.read_csv('Graph1.csv')
print(df1)
df1.describe()
# Out:
#                        Entity  Firms with female top manager
# 0         East Asia & Pacific                      32.830769
# 1       Europe & Central Asia                      18.513889
# 2   Latin America & Caribbean                      20.061538
# 3  Middle East & North Africa                       6.500000
# 4                  South Asia                      10.957143
# 5          Sub-Saharan Africa                      16.188235
# 6                       World                      18.006140
#        Firms with female top manager
# count                       7.000000
# mean                       17.579674
# std                         8.249883
# min                         6.500000
# 25%                        13.572689
# 50%                        18.006140
# 75%                        19.287714
# max                        32.830769

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
g=df1.plot()
type(g)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
g1 = df1[['Firms with female top manager','Entity']].plot(
    kind="bar",
    title="Share of firms with female top managers, 2020",
    color="darkturquoise"
)

# %%
list(df1.columns)
# Out:
# ['Entity', 'Firms with female top manager']

# %%
df1.columns
# Out:
# Index(['Entity', 'Firms with female top manager'], dtype='object')

# %%
df1.head(2)
# Out:
#                   Entity  Firms with female top manager
# 0    East Asia & Pacific                      32.830769
# 1  Europe & Central Asia                      18.513889

# %%
df1.index.values
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
df1.set_index("Entity",drop=True,inplace=True)

# %%
df1.index.values
# Out:
# array(['East Asia & Pacific', 'Europe & Central Asia',
#        'Latin America & Caribbean', 'Middle East & North Africa',
#        'South Asia', 'Sub-Saharan Africa', 'World'], dtype=object)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-01b01c459ade> in <module>
# ----> 1 g3 = df1[['Firms with female top manager',"Entity"]].plot(
#       2     kind="bar",
#       3     title="Share of firms with female top managers, 2020",
#       4     color="darkturquoise"
#       5 )
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# ...

# %%
g3 = df1.plot(
    kind="bar",
    title="Share of firms with female top managers, 2020",
    color="darkturquoise"
)

# %%
plt.savefig('graph1.jpg')
